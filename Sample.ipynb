# %% [markdown]
# <a href="https://colab.research.google.com/github/prajeeta15/ANOVA/blob/main/Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import scipy.special
import scipy.stats
import pandas as pd
import matplotlib.pyplot as plt
import json
from google.colab import files

# %%
sp.stats.f.ppf(.95, 3, 328)
# Out:
# 2.6321415117354894

# %%
df = pd.read_json('/content/drive/MyDrive/sample_data.json')
df.head()
# Out:
#    Attribute1  Attribute2  Attribute3
# 0       843.6       844.0       843.8
# 1       843.8       843.8       843.7
# 2       843.6       843.6       843.6
# 3       844.2       843.7       844.1
# 4       844.1       844.7       843.9

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(df.columns)
df
# Out:
# Index(['Attribute1', 'Attribute2', 'Attribute3'], dtype='object')
#    Attribute1  Attribute2  Attribute3
# 0       843.6       844.0       843.8
# 1       843.8       843.8       843.7
# 2       843.6       843.6       843.6
# 3       844.2       843.7       844.1
# 4       844.1       844.7       843.9
# 5       843.8       844.7       844.0
# 6       844.0       844.2       843.8
# 7       843.8       844.0       843.8
# 8       843.8       843.8       843.8
# 9       843.8       843.8       843.7

# %%
squared_deviation_A1_A2 = (df['Attribute1'] - df['Attribute2'])**2
sum_squared_deviation_A1_A2 = squared_deviation_A1_A2.sum()

squared_deviation_A1_A3 = (df['Attribute1'] - df['Attribute3'])**2
sum_squared_deviation_A1_A3 = squared_deviation_A1_A3.sum()

squared_deviation_A2_A3 = (df['Attribute2'] - df['Attribute3'])**2
sum_squared_deviation_A2_A3 = squared_deviation_A2_A3.sum()



print(pd.DataFrame({'Squared deviation A1 - A2': [squared_deviation_A1_A2],
                    'Squared deviation A1 - A3': [squared_deviation_A1_A3],
                    'Squared deviation A2 - A3': [squared_deviation_A2_A3],
                     'Sum of Squared Deviation A1-A2': [sum_squared_deviation_A1_A2],
                     'Sum of Squared Deviation A1-A3': [sum_squared_deviation_A1_A3],
                     'Sum of Squared Deviation A2-A3': [sum_squared_deviation_A2_A3]}))
# Out:
#                            Squared deviation A1 - A2  \
# 0  0    0.16
# 1    0.00
# 2    0.00
# 3    0.25
# 4    0...
#
#                            Squared deviation A1 - A3  \
# 0  0    0.04
# 1    0.01
# 2    0.00
# 3    0.01
# 4    0...
#
#                            Squared deviation A2 - A3  \
# 0  0    0.04
# 1    0.01
# 2    0.00
# 3    0.16
# 4    0...
#
#    Sum of Squared Deviation A1-A2  Sum of Squared Deviation A1-A3  \
# 0                            1.66                            0.19
#
#    Sum of Squared Deviation A2-A3
# 0                            1.55

# %%
import pandas as pd
sum_of_rows = df.sum(axis=1)
sum_of_columns = df.sum(axis=0)
mean_of_rows = df.mean(axis=1)
mean_of_columns = df.mean(axis=0)
variance_of_rows = df.var(axis=1)
variance_of_columns = df.var(axis=0)
results_df = pd.DataFrame({
    'Sum of Rows': sum_of_rows,
    'Sum of Columns': sum_of_columns,
    'Mean of Rows': mean_of_rows,
    'Mean of Columns': mean_of_columns,
    'Variance of Rows': variance_of_rows,
    'Variance of Columns': variance_of_columns
})
print(results_df.to_string())
# Out:
#             Sum of Rows  Sum of Columns  Mean of Rows  Mean of Columns  Variance of Rows  Variance of Columns
# 0                2531.4             NaN    843.800000              NaN      4.000000e-02                  NaN
# 1                2531.3             NaN    843.766667              NaN      3.333333e-03                  NaN
# 2                2530.8             NaN    843.600000              NaN      0.000000e+00                  NaN
# 3                2532.0             NaN    844.000000              NaN      7.000000e-02                  NaN
# 4                2532.7             NaN    844.233333              NaN      1.733333e-01                  NaN
# 5                2532.5             NaN    844.166667              NaN      2.233333e-01                  NaN
# 6                2532.0             NaN    844.000000              NaN      4.000000e-02                  NaN
# 7                2531.6             NaN    843.866667              NaN      1.333333e-02                  NaN
# 8                2531.4             NaN    843.800000              NaN      1.938705e-26                  NaN
# 9                2531.3             NaN    843.766667              NaN      3.333333e-03                  NaN
# Attribute1          NaN          8438.5           NaN           843.85               NaN             0.038333
# Attribute2          NaN          8440.3           NaN           844.03               NaN             0.153444
# Attribute3          NaN          8438.2           NaN           843.82               NaN             0.021778

# %%
# !pip install scipy
import scipy as sp
from scipy.stats import f as scipysf
grand_mean = df.values.mean()
row_means = df.mean(axis=1)

SSB = df.shape[1] * sum((row_means - grand_mean)**2)
deviations = df.sub(row_means,axis=0)
SSW = (deviations**2).sum().sum()
df_rows = df.shape[0] - 1
MSB = SSB / df_rows
df_within_rows = (df.shape[0]-1) * (df.shape[1] - 1)
MSW = SSW / df_within_rows

SSC = df.shape[0] * sum((mean_of_columns - grand_mean)**2)
SSE=SSW-SSC
MSE = SSE / df_within_rows
F_rows = MSB / MSE
p_value_rows = 1 - scipysf.cdf(F_rows, df_rows, df_within_rows)
column_means = df.mean(axis=0)

df_columns = df.shape[1] - 1
MSC = SSC / df_columns


F_columns = MSC / MSE

p_value_columns = 1 - scipysf.cdf(F_columns, df_columns, df_within_rows)


print("Sum of squares between rows (SSB):", SSB)
print("Sum of squares within rows (SSW):", SSW)
print("Degrees of freedom for rows:", df_rows)
print("Mean squares between rows (MSB):", MSB)
print("Mean squares within rows (MSW):", MSE)
print("F value of rows:", F_rows)
print("P value of rows:", p_value_rows)
print("Sum of squares of columns (SSC):", SSC)
print("Degrees of freedom for columns:", df_columns)
print("Mean squares of columns (MSC):", MSC)
print("F value of columns:", F_columns)
print("P value of columns:", p_value_columns)

probability = 0.05
deg_freedom1 = df_rows
deg_freedom2 = df_within_rows
deg_freedom3 = df_columns
f_crit_rows = scipysf.ppf(1 - probability, deg_freedom1, deg_freedom2)
f_crit_columns = scipysf.ppf(1 - probability, deg_freedom3, deg_freedom2)
print("Critical F value for rows:", f_crit_rows)
print("Critical F value for columns:", f_crit_columns)
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from scipy) (1.25.2)
# Sum of squares between rows (SSB): 1.0466666666668545
# Sum of squares within rows (SSW): 1.1333333333334774
# Degrees of freedom for rows: 9
# Mean squares between rows (MSB): 0.11629629629631716
# Mean squares within rows (MSW): 0.04862962962963086
# F value of rows: 2.3914699162227597
# P value of rows: 0.05513499198371463
# Sum of squares of columns (SSC): 0.2580000000001219
# Degrees of freedom for columns: 2
# Mean squares of columns (MSC): 0.12900000000006095
# F value of columns: 2.652703731912839
# P value of columns: 0.09780076286907302
# Critical F value for rows: 2.4562811491592678
# Critical F value for columns: 3.554557145661787

# %%
print("2-way ANOVA Results")
print()
print("Source of Variation | Sum of Squares | Degrees of Freedom | Mean Square | F Value | P Value  | F-crit  ")
print("------------------ | --------------- | -----------------  | ----------- | --------| -------- |")
print(f"Rows             | {SSB:.4f}            | {df_rows}                  | {MSB:.4f}      | {F_rows:.4f}  | {p_value_rows:.4f}   | {f_crit_rows:.4f}")
print(f"Columns          | {SSC:.4f}            | {df_columns}                  | {MSC:.4f}      | {F_columns:.4f}  | {p_value_columns:.4f}   |{f_crit_columns: .4f}")
print(f"Within Rows      | {SSW:.4f}            | {df_within_rows}                 | {MSW:.4f}      |                    |                     ")
print(f"Error            | {SSE:.4f}            | {df_within_rows}                 | {MSE:.4f}      |                    |                      ")
# Out:
# 2-way ANOVA Results
#
# Source of Variation | Sum of Squares | Degrees of Freedom | Mean Square | F Value | P Value  | F-crit
# ------------------ | --------------- | -----------------  | ----------- | --------| -------- |
# Rows             | 1.0467            | 9                  | 0.1163      | 2.3915  | 0.0551   | 2.4563
# Columns          | 0.2580            | 2                  | 0.1290      | 2.6527  | 0.0978   | 3.5546
# Within Rows      | 1.1333            | 18                 | 0.0630      |                    |
# Error            | 0.8753            | 18                 | 0.0486      |                    |

# %%
F_crit_at_95 = 2.39281411
if (F_rows > F_crit_at_95) and (p_value_rows < 0.05):
    B = False
    print("FAIL HOMOGENITY TEST")
else:
    B = True
    print("PASS HOMOGENITY TEST")
# Out:
# PASS HOMOGENITY TEST

# %%
anova_test = ["SSB:", SSB, "SSC:", SSC, "SSW:", SSW, "SSE:", SSE,
"df_rows:", df_rows, "df_columns:", df_columns, "df_within_rows:", df_within_rows, "df_within_rows:", df_within_rows,
                "MSB:", MSB, "MSC: ", MSC, "MSW:", MSW, "MSE:", MSE,
                "degree of freedom of rows :" , F_rows,"degree of freedom of columns: " , F_columns, 0, 0,
               "P value of rows: " , p_value_rows,"P value of columns: " , p_value_columns, 0, 0,
               "F-critical at 95% confidence: ", F_crit_at_95, "Pass Homogenity?: ", B]

with open('anova_results.json', 'w') as json_file:
    json.dump(anova_test, json_file, indent=4)
